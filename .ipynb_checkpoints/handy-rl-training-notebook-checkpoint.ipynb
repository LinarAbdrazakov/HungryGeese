# %% [markdown]
# ### This notebook is based on pytorch implementation of handyrl (https://github.com/DeNA/HandyRL) with minor changes
#
# The inference part is taken from : https://www.kaggle.com/yuricat/smart-geese-trained-by-reinforcement-learning. As mentioned here https://www.kaggle.com/c/hungry-geese/discussion/218190, this model was trained for around 1,500 epochs with 800,000 games.

# %%
#!pip install pyyaml

# %%
import os
import sys
import yaml

# %% [markdown]
# # Clone handyrl (keep your own fork for flexibility)

# %%
# !git clone https://github.com/kumar-shubham-ml/HandyRL.git
#!git clone https://github.com/Dena/HandyRL.git
#!cp -r HandyRL/. .

# %% [markdown]
# ## Prepare Config

# %%
# %%writefile config.yaml
#
# env_args:
#     env: 'HungryGeese'
#     source: 'handyrl.envs.kaggle.hungry_geese'
#
#
# train_args:
#     turn_based_training: False  # always False for Hungry Geese
#     observation: False
#     gamma: 0.999
#     forward_steps: 100
#     compress_steps: 4
#     entropy_regularization: 2.0e-3
#     entropy_regularization_decay: 0.3
#     update_episodes: 500
#     batch_size: 400  # GPU memory 10GB
#     minimum_episodes: 100
#     maximum_episodes: 5000  # RAM 64GB
#     eval_rate: 0.1
#     epochs: 240
#     num_batchers: 6
#     worker:
#         num_parallel: 8
#     lambda: 0.7
#     policy_target: 'TD'
#     value_target: 'TD'
#     seed: 0
#     restart_epoch: 120
#
#
# worker_args:
#     server_address: ''
#     num_parallel: 8
# Out:
# Overwriting config.yaml

# %%
# !ls
# Out:
# 120.pth			   handy-rl-training-notebook.ipynb
# HandyRL			   handyrl
# LICENSE			   main.py
# Petya.py		   models
# README.md		   poetry.lock
# Serega.py		   pyproject.toml
# Vasya.py		   requirements-dev.txt
# alphageese-baseline.ipynb  requirements.txt
# config.yaml		   rl
# docs			   submission.py
# env			   tests

# %% [markdown]
# ## Install Necessary Dependencies

# %%
# !pip install -r requirements.txt

# %%
# !pip install kaggle-environments

# %% [markdown]
# # Training

# %%
from handyrl.train import train_main 
from handyrl.train import train_server_main
from handyrl.worker import worker_main
from handyrl.evaluation import eval_main
from handyrl.evaluation import eval_server_main
from handyrl.evaluation import eval_client_main

# %%
with open('config.yaml') as f:
    args = yaml.safe_load(f)
print(args)
# Out:
# {'env_args': {'env': 'HungryGeese', 'source': 'handyrl.envs.kaggle.hungry_geese'}, 'train_args': {'turn_based_training': False, 'observation': False, 'gamma': 0.999, 'forward_steps': 100, 'compress_steps': 4, 'entropy_regularization': 0.002, 'entropy_regularization_decay': 0.3, 'update_episodes': 500, 'batch_size': 400, 'minimum_episodes': 100, 'maximum_episodes': 5000, 'eval_rate': 0.1, 'epochs': 240, 'num_batchers': 3, 'worker': {'num_parallel': 2}, 'lambda': 0.7, 'policy_target': 'TD', 'value_target': 'TD', 'seed': 0, 'restart_epoch': 120}, 'worker_args': {'server_address': '', 'num_parallel': 4}}

# %%
train_main(args)
# Out:
# Loading environment football failed: No module named 'gfootball'
# started batcher 0
# started batcher 1waiting training
#
# started batcher 2
# started gather 0
# opened worker 0
# opened worker 1
# started server
# Process Process-2:
# Process Process-1:
# Process Process-3:
# Process Process-4:1:
# Process Process-4:2:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/root/miniconda/envs/py37/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/root/miniconda/envs/py37/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/root/miniconda/envs/py37/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/root/miniconda/envs/py37/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/root/miniconda/envs/py37/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/handy_rl/handyrl/train.py", line 276, in _worker
#     episodes = conn.recv()
#   File "/root/miniconda/envs/py37/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
#   File "/handy_rl/handyrl/train.py", line 276, in _worker
#     episodes = conn.recv()
#   File "/root/miniconda/envs/py37/lib/python3.7/multiprocessing/connection.py", line 250, in recv
#     buf = self._recv_bytes()
#   File "/handy_rl/handyrl/train.py", line 276, in _worker
#     episodes = conn.recv()
#   File "/root/miniconda/envs/py37/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/root/miniconda/envs/py37/lib/python3.7/multiprocessing/connection.py", line 250, in recv
#     buf = self._recv_bytes()
#   File "/root/miniconda/envs/py37/lib/python3.7/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/root/miniconda/envs/py37/lib/python3.7/multiprocessing/connection.py", line 250, in recv
#     buf = self._recv_bytes()
#   File "/root/miniconda/envs/py37/lib/python3.7/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/root/miniconda/envs/py37/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/root/miniconda/envs/py37/lib/python3.7/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
#   File "/root/miniconda/envs/py37/lib/python3.7/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/root/miniconda/envs/py37/lib/python3.7/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
# KeyboardInterrupt
#   File "/root/miniconda/envs/py37/lib/python3.7/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
#   File "/handy_rl/handyrl/worker.py", line 87, in open_worker
#     worker.run()
# KeyboardInterrupt
#   File "/handy_rl/handyrl/worker.py", line 77, in run
#     result = self.evaluator.execute(models, args)
# KeyboardInterrupt
#   File "/root/miniconda/envs/py37/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/handy_rl/handyrl/evaluation.py", line 166, in execute
#     outcome = exec_match(self.env, agents, None)
#   File "/handy_rl/handyrl/evaluation.py", line 97, in exec_match
#     if env.step(actions):
#   File "/root/miniconda/envs/py37/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/handy_rl/handyrl/envs/kaggle/hungry_geese.py", line 165, in step
#     obs = self.env.step(actions[0])
#   File "/handy_rl/handyrl/worker.py", line 87, in open_worker
#     worker.run()
#   File "/root/miniconda/envs/py37/lib/python3.7/site-packages/kaggle_environments/core.py", line 382, in step
#     actions, logs = runner.act(action)
#   File "/handy_rl/handyrl/worker.py", line 74, in run
#     episode = self.generator.execute(models, args)
#   File "/root/miniconda/envs/py37/lib/python3.7/site-packages/kaggle_environments/core.py", line 645, in act
#     results = list(map(act_agent, act_args))
#   File "/handy_rl/handyrl/generation.py", line 91, in execute
#     episode = self.generate(models, args)
#   File "/root/miniconda/envs/py37/lib/python3.7/site-packages/kaggle_environments/core.py", line 101, in act_agent
#     return agent.act(state["observation"])
#   File "/handy_rl/handyrl/generation.py", line 59, in generate
#     err = self.env.step(moment['action'])
#   File "/root/miniconda/envs/py37/lib/python3.7/site-packages/kaggle_environments/agent.py", line 157, in act
#     action = self.agent(*args)
#   File "/handy_rl/handyrl/envs/kaggle/hungry_geese.py", line 165, in step
#     obs = self.env.step(actions[0])
#   File "/root/miniconda/envs/py37/lib/python3.7/site-packages/kaggle_environments/agent.py", line 129, in callable_agent
#     if callable(agent) \
#   File "Petya.py", line 305, in alphageese_agent
#     mcts.getActionProb(obs, timelimit=config.actTimeout))]
#   File "/root/miniconda/envs/py37/lib/python3.7/site-packages/kaggle_environments/core.py", line 382, in step
#     actions, logs = runner.act(action)
#   File "/root/miniconda/envs/py37/lib/python3.7/site-packages/kaggle_environments/core.py", line 645, in act
#     results = list(map(act_agent, act_args))
#   File "Petya.py", line 34, in getActionProb
#     self.search(obs, self.last_obs)
#   File "/root/miniconda/envs/py37/lib/python3.7/site-packages/kaggle_environments/core.py", line 101, in act_agent
#     return agent.act(state["observation"])
#   File "Petya.py", line 94, in search
#     values = self.search(next_obs, obs)
#   File "/root/miniconda/envs/py37/lib/python3.7/site-packages/kaggle_environments/agent.py", line 157, in act
#     action = self.agent(*args)
#   File "Petya.py", line 94, in search
#     values = self.search(next_obs, obs)
#   File "/root/miniconda/envs/py37/lib/python3.7/site-packages/kaggle_environments/agent.py", line 129, in callable_agent
#     if callable(agent) \
#   File "Petya.py", line 94, in search
#     values = self.search(next_obs, obs)
#   File "Petya.py", line 305, in alphageese_agent
#     mcts.getActionProb(obs, timelimit=config.actTimeout))]
#   [Previous line repeated 1 more time]
#   File "Petya.py", line 34, in getActionProb
#     self.search(obs, self.last_obs)
#   File "Petya.py", line 56, in search
#     self.Ps[(s, i)], values[i] = self.nn_agent.predict(obs, last_obs, i)
#   File "Petya.py", line 94, in search
#     values = self.search(next_obs, obs)
#   File "Petya.py", line 94, in search
#     values = self.search(next_obs, obs)
#   File "Petya.py", line 268, in predict
#     p, v = self.model(xt)
#   File "Petya.py", line 56, in search
#     self.Ps[(s, i)], values[i] = self.nn_agent.predict(obs, last_obs, i)
#   File "/root/miniconda/envs/py37/lib/python3.7/site-packages/torch/nn/modules/module.py", line 889, in _call_impl
#     result = self.forward(*input, **kwargs)
#   File "Petya.py", line 268, in predict
#     p, v = self.model(xt)
#   File "Petya.py", line 236, in forward
#     p_expanded, v_expanded = self.forward_helper(x_expanded)
#   File "Petya.py", line 217, in forward_helper
#     h = F.relu_(h + block(h))
#   File "/root/miniconda/envs/py37/lib/python3.7/site-packages/torch/nn/modules/module.py", line 889, in _call_impl
#     result = self.forward(*input, **kwargs)
#   File "/root/miniconda/envs/py37/lib/python3.7/site-packages/torch/nn/modules/module.py", line 889, in _call_impl
#     result = self.forward(*input, **kwargs)
#   File "Petya.py", line 236, in forward
#     p_expanded, v_expanded = self.forward_helper(x_expanded)
#   File "Petya.py", line 201, in forward
#     h = self.conv(h)
#   File "Petya.py", line 217, in forward_helper
#     h = F.relu_(h + block(h))
#   File "/root/miniconda/envs/py37/lib/python3.7/site-packages/torch/nn/modules/module.py", line 889, in _call_impl
#     result = self.forward(*input, **kwargs)
#   File "/root/miniconda/envs/py37/lib/python3.7/site-packages/torch/nn/modules/module.py", line 889, in _call_impl
#     result = self.forward(*input, **kwargs)
#   File "/root/miniconda/envs/py37/lib/python3.7/site-packages/torch/nn/modules/conv.py", line 399, in forward
#     return self._conv_forward(input, self.weight, self.bias)
#   File "Petya.py", line 201, in forward
#     h = self.conv(h)
#   File "/root/miniconda/envs/py37/lib/python3.7/site-packages/torch/nn/modules/conv.py", line 396, in _conv_forward
#     self.padding, self.dilation, self.groups)
#   File "/root/miniconda/envs/py37/lib/python3.7/site-packages/torch/nn/modules/module.py", line 889, in _call_impl
#     result = self.forward(*input, **kwargs)
# KeyboardInterrupt
#   File "/root/miniconda/envs/py37/lib/python3.7/site-packages/torch/nn/modules/conv.py", line 399, in forward
#     return self._conv_forward(input, self.weight, self.bias)
# closed worker 1
#   File "/root/miniconda/envs/py37/lib/python3.7/site-packages/torch/nn/modules/conv.py", line 396, in _conv_forward
#     self.padding, self.dilation, self.groups)
# KeyboardInterrupt
# closed worker 0
# disconnected
# disconnected
# Process Process-4:
# Traceback (most recent call last):
#   File "/root/miniconda/envs/py37/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/root/miniconda/envs/py37/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/handy_rl/handyrl/worker.py", line 160, in gather_loop
#     gather.run()
#   File "/handy_rl/handyrl/worker.py", line 121, in run
#     conn, (command, args) = self.recv()
#   File "/handy_rl/handyrl/connection.py", line 221, in recv
#     return self.input_queue.get()
#   File "/root/miniconda/envs/py37/lib/python3.7/queue.py", line 170, in get
#     self.not_empty.wait()
#   File "/root/miniconda/envs/py37/lib/python3.7/threading.py", line 296, in wait
#     waiter.acquire()
# KeyboardInterrupt
# finished gather 0
# finished training
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_20409/192081635.py in <module>
# ----> 1 train_main(args)
#
# /handy_rl/handyrl/train.py in train_main(args)
#     651     prepare_env(args['env_args'])  # preparing environment is needed in stand-alone mode
#     652     learner = Learner(args=args)
# --> 653     learner.run()
#     654
#     655
#
# /handy_rl/handyrl/train.py in run(self)
#     642             # open generator, evaluator
#     643             self.worker.run()
# --> 644             self.server()
#     645
#     646         finally:
#
# /handy_rl/handyrl/train.py in server(self)
#     566             next_update_episodes = prev_update_episodes + self.args['update_episodes']
#     567             while not self.shutdown_flag and self.num_episodes < next_update_episodes:
# --> 568                 conn, (req, data) = self.worker.recv()
#     569                 multi_req = isinstance(data, list)
#     570                 if not multi_req:
#
# /handy_rl/handyrl/connection.py in recv(self)
#     219
#     220     def recv(self):
# --> 221         return self.input_queue.get()
#     222
#     223     def send(self, conn, send_data):
#
# ~/miniconda/envs/py37/lib/python3.7/queue.py in get(self, block, timeout)
#     168             elif timeout is None:
#     169                 while not self._qsize():
# --> 170                     self.not_empty.wait()
#     171             elif timeout < 0:
#     172                 raise ValueError("'timeout' must be a non-negative number")
#
# ~/miniconda/envs/py37/lib/python3.7/threading.py in wait(self, timeout)
#     294         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     295             if timeout is None:
# --> 296                 waiter.acquire()
#     297                 gotit = True
#     298             else:
#
# KeyboardInterrupt:

# %%
# !sysctl kernel.dmesg_restrict=1
# Out:
# sysctl: setting key "kernel.dmesg_restrict": Read-only file system

# %%
# !sudo dmesg
# Out:
# dmesg: read kernel buffer failed: Operation not permitted

# %%
# !dmesg | egrep -i "killed process"
# Out:
# dmesg: read kernel buffer failed: Operation not permitted

# %%
# !pip install --upgrade ipykernel

# %%
# !ls

# %%
# !ls models/

# %%
! du -h

# %%
# !cp models/latest.pth /tmp/
# !rm -r *
# !cp /tmp/latest.pth .
# !ls

# %% [markdown]
# # Preparing Submission File

# %%
import pickle
import bz2
import base64
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F

model_path = 'models/latest.pth'

weights = torch.load(model_path)

PARAM = base64.b64encode(bz2.compress(pickle.dumps(weights)))
state_dict = pickle.loads(bz2.decompress(base64.b64decode(PARAM)))

# %%
PARAM.decode("utf-8")
# Out:
# '...'

# %%
type(state_dict)
# Out:
# collections.OrderedDict

# %%
# %%writefile submission.py

# This is a lightweight ML agent trained by self-play.
# After sharing this notebook,
# we will add Hungry Geese environment in our HandyRL library.
# https://github.com/DeNA/HandyRL
# We hope you enjoy reinforcement learning!


import pickle
import bz2
import base64
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F


# Neural Network for Hungry Geese

class TorusConv2d(nn.Module):
    def __init__(self, input_dim, output_dim, kernel_size, bn):
        super().__init__()
        self.edge_size = (kernel_size[0] // 2, kernel_size[1] // 2)
        self.conv = nn.Conv2d(input_dim, output_dim, kernel_size=kernel_size)
        self.bn = nn.BatchNorm2d(output_dim) if bn else None

    def forward(self, x):
        h = torch.cat([x[:,:,:,-self.edge_size[1]:], x, x[:,:,:,:self.edge_size[1]]], dim=3)
        h = torch.cat([h[:,:,-self.edge_size[0]:], h, h[:,:,:self.edge_size[0]]], dim=2)
        h = self.conv(h)
        h = self.bn(h) if self.bn is not None else h
        return h


class GeeseNet(nn.Module):
    def __init__(self):
        super().__init__()
        layers, filters = 12, 32
        self.conv0 = TorusConv2d(17, filters, (3, 3), True)
        self.blocks = nn.ModuleList([TorusConv2d(filters, filters, (3, 3), True) for _ in range(layers)])
        self.head_p = nn.Linear(filters, 4, bias=False)
        self.head_v = nn.Linear(filters * 2, 1, bias=False)

    def forward(self, x):
        h = F.relu_(self.conv0(x))
        for block in self.blocks:
            h = F.relu_(h + block(h))
        h_head = (h * x[:,:1]).view(h.size(0), h.size(1), -1).sum(-1)
        h_avg = h.view(h.size(0), h.size(1), -1).mean(-1)
        p = self.head_p(h_head)
        v = torch.tanh(self.head_v(torch.cat([h_head, h_avg], 1)))

        return {'policy': p, 'value': v}


# Input for Neural Network

def make_input(obses):
    b = np.zeros((17, 7 * 11), dtype=np.float32)
    obs = obses[-1]

    for p, pos_list in enumerate(obs['geese']):
        # head position
        for pos in pos_list[:1]:
            b[0 + (p - obs['index']) % 4, pos] = 1
        # tip position
        for pos in pos_list[-1:]:
            b[4 + (p - obs['index']) % 4, pos] = 1
        # whole position
        for pos in pos_list:
            b[8 + (p - obs['index']) % 4, pos] = 1
            
    # previous head position
    if len(obses) > 1:
        obs_prev = obses[-2]
        for p, pos_list in enumerate(obs_prev['geese']):
            for pos in pos_list[:1]:
                b[12 + (p - obs['index']) % 4, pos] = 1

    # food
    for pos in obs['food']:
        b[16, pos] = 1

    return b.reshape(-1, 7, 11)


# Load PyTorch Model

PARAM = b'XXXXXXXXXX'

state_dict = pickle.loads(bz2.decompress(base64.b64decode(PARAM)))
model = GeeseNet()
model.load_state_dict(state_dict)
model.eval()


# Main Function of Agent

obses = []

def agent(obs, _):
    obses.append(obs)
    x = make_input(obses)
    with torch.no_grad():
        xt = torch.from_numpy(x).unsqueeze(0)
        o = model(xt)
    p = o['policy'].squeeze(0).detach().numpy()

    actions = ['NORTH', 'SOUTH', 'WEST', 'EAST']
    return actions[np.argmax(p)]

# %%
# Read in the submission file
with open('submission.py',) as file :
    filedata = file.read()

# Replace the target string
filedata = filedata.replace('XXXXXXXXXX', PARAM.decode("utf-8") )

# Write the file out again
with open('submission.py','w') as file:
    file.write(filedata)

# %%
with open('submission.py',) as file :
    filedata = file.read()

# %%
# print(filedata)

# %%
from kaggle_environments import make
env = make("hungry_geese", debug=True)

env.reset()
env.run(['submission.py', 'submission.py', 'submission.py', 'submission.py'])
env.render(mode="ipython", width=800, height=700)
